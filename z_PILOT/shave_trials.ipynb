# %%
import numpy as np
import pandas as pd

block = ['S3-IL-B1-Number-20191022-165937.pkl',
'S3-IL-B2-Space-20191022-172446.pkl',
'S3-IL-B3-Number-20191022-175042.pkl',
'S3-IL-B4-Space-20191022-180848.pkl']

for iblock in range(0,4):
    currblock = pd.read_pickle(block[0])
    shavedblock = currblock[0:150]
    
    filename_pickle = block[iblock]
    shavedblock.to_pickle(filename_pickle)
    print(filename_pickle)
# Out:
# S3-IL-B1-Number-20191022-165937.pkl
# S3-IL-B2-Space-20191022-172446.pkl
# S3-IL-B3-Number-20191022-175042.pkl
# S3-IL-B4-Space-20191022-180848.pkl

# %%
pd.read_pickle('S3-IL-B1-Number-20191022-165937.pkl')
# Out:
#      Num_block  Block_ID  Trial_ID  Resp_loc  Resp_conf  Correct    RT_resp  \
# 0          1.0       1.0       1.0      53.0       7.75      0.0   5.007405
# 1          1.0       1.0       2.0      49.0      11.25      1.0   6.408600
# 2          1.0       1.0       3.0      50.0       4.00      0.0   3.643274
# 3          1.0       1.0       4.0      48.0      10.50      1.0   5.769908
# 4          1.0       1.0       5.0      41.0      12.25      1.0   8.695259
# 5          1.0       1.0       6.0      37.0       7.75      1.0   6.770577
# 6          1.0       1.0       7.0      50.0       8.75      1.0   5.465928
# 7          1.0       1.0       8.0      60.0       8.75      1.0   5.924979
# 8          1.0       1.0       9.0      37.0       9.50      1.0   6.772540
# 9          1.0       1.0      10.0      24.0      16.25      1.0   7.980658
# 10         1.0       1.0      11.0      58.0      14.50      1.0   9.425842
# ...

# %%
# incbloc = 'INCOMPLETE_S1-AW-B5-Space-20191023-123746.pkl'
# compbloc = 'S1-AW-B5-Space-20191023-124613.pkl'

# inc = pd.read_pickle(incbloc)
# comp = pd.read_pickle(compbloc)
# last = comp[len(inc):len(comp)]

# data = {'Num_block':[],
#         'Block_ID':[],
#         'Trial_ID':[],
#         'Resp_loc':[], 
#         'Resp_conf':[], 
#         'Correct':[],
#         'RT_resp':[], 
#         'RT_conf':[],
#         'Wager':[],
#         'x':[],
#         'N':[],
#         'x_mean':[],
#         'Mouse_track':[]}

# concat = pd.DataFrame(data)
# concat = concat.append(inc,ignore_index=True,sort=False)
# concat = concat.append(last,ignore_index=True,sort=False)

# concat.to_pickle(compbloc)
# # filename_pickle = block[iblock]
# # shavedblock.to_pickle(filename_pickle)
# # print(filename_pickle)
